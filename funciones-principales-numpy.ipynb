# %% [markdown]
# ### Importando librerías

# %% [markdown]
# Vamos a ver cuáles son las funciones que se utilizan normalmente con NumPy cuando analizamos los datos.

# %%
import numpy as np

# %% [markdown]
# Creamos un vector de 10 valores con numeros aleatorios del 1 al 20

# %%
arr = np.random.randint(1,20,10)

# %% [markdown]
# Ese vector cambiaremos su forma y lo transformaremos a una matriz de 2 x 5

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[19,  9, 15, 15, 16],
#        [18, 19, 16, 12, 14]])

# %%
arr
# Out:
# array([19,  9, 15, 15, 16, 18, 19, 16, 12, 14])

# %% [markdown]
# ### Max

# %% [markdown]
# .max Para el máximo

# %%
arr.max()
# Out:
# 19

# %%
matriz
# Out:
# array([[19,  9, 15, 15, 16],
#        [18, 19, 16, 12, 14]])

# %% [markdown]
# Podemos regresar los máximos de cada fila o columna especificando el eje
# Recuerda que:
# ![image.png](attachment:image.png)

# %%
matriz.max(0)
# Out:
# array([19, 19, 16, 15, 16])

# %% [markdown]
# ### Argmax

# %% [markdown]
# También tenemos .argmax() que nos devuelve la posición del elemento
# ![image.png](attachment:image.png)

# %%
arr.argmax()
# Out:
# 0

# %% [markdown]
# En el caso de la matriz nos muestra con un 1 dónde se encuentra el mayor entre las columnas

# %%
matriz.argmax(0)
# Out:
# array([0, 1, 1, 0, 0])

# %% [markdown]
# ### Min

# %% [markdown]
# De forma análoga tenemos .min()

# %%
arr.min()
# Out:
# 9

# %%
matriz.min(0)
# Out:
# array([18,  9, 15, 12, 14])

# %% [markdown]
# ### Argmin

# %%
arr.argmin()
# Out:
# 1

# %% [markdown]
# Podemos regresar los minimos de cada fila o columna especificando el eje
# Recuerda que:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
matriz.argmin(1)
# Out:
# array([1, 3])

# %% [markdown]
# ### Ptp

# %% [markdown]
# Podemos saber la diferencia entre el valor más bajo con el más alto.

# %%
arr
# Out:
# array([19,  9, 15, 15, 16, 18, 19, 16, 12, 14])

# %%
arr.ptp()
# Out:
# 10

# %% [markdown]
# Esto mismo se puede aplicar en matrices para el siguiente caso obtenemos la diferencia del valor mas altro y mas bajo, por columna
# ![image.png](attachment:image.png)

# %%
matriz.ptp(0)
# Out:
# array([ 1, 10,  1,  3,  2])

# %% [markdown]
# # Analisis Estadistico

# %% [markdown]
# *Ordenar los elementos:*

# %% [markdown]
# ### Sort

# %%
arr.sort()
arr
# Out:
# array([ 9, 12, 14, 15, 15, 16, 16, 18, 19, 19])

# %% [markdown]
# ### Percentile

# %%
np.percentile(arr,50)
# Out:
# 15.5

# %% [markdown]
# ### Median

# %%
np.median(arr)
# Out:
# 15.5

# %%
np.median(matriz,1)
# Out:
# array([14., 18.])

# %% [markdown]
# ### Standard Deviation (std)

# %%
np.std(arr)
# Out:
# 8.81

# %% [markdown]
# ### Variance (Var)

# %%
np.var(arr)
# ó 
np.std(arr) ** 2
# Out:
# 8.81

# %% [markdown]
# ### Mean

# %%
np.mean(arr)
# Out:
# 15.3

# %% [markdown]
# Lo mismo aplica para las matrices.

# %%
np.median(matriz, 1) #Se aplicaria para filas

# %% [markdown]
# ### Concatenate

# %% [markdown]
# Se pueden unir dos arrays

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
np.concatenate((a,b),axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-17464568486c> in <module>()
# ----> 1 np.concatenate((a,b),axis=0)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
a.ndim
b.ndim
# Out:
# 1

# %% [markdown]
# El error anterior es debido a que ‘a’ tiene 2 dimensiones, mientras que ‘b’ tiene 1.
# Debemos poner ‘b’ en 2 dimensiones también

# %%
b = np.expand_dims(b,axis=0)

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b
# Out:
# array([[5, 6]])

# %%
np.concatenate((a,b),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-644816af0704> in <module>()
# ----> 1 np.concatenate((a,b),axis=1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 1

# %% [markdown]
# Como ‘b’ es una fila y no una columna, no se puede concatenar a menos que se aplique la transpuesta.
#
# La transpuesta pone nuestro array en sentido opuesto, si el array original es (1,2), con la transpuesta quedará (2,1)

# %%
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %% [markdown]
# ### Transpuesta

# %%
b.T
# Out:
# array([[5],
#        [6]])

# %% [markdown]
# ```np.concatenate((a,b.T), axis = 1)```
# ---> array([[1, 2, 5],
#                [3, 4, 6]])
